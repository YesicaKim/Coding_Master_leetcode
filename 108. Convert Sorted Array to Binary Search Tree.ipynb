# %% [markdown]
# ### 101. Symmetric Tree
#
# Given an integer array nums where the elements are sorted in ascending order, convert it to a height-balanced binary search tree.
#
# A height-balanced binary tree is a binary tree in which the depth of the two subtrees of every node never differs by more than one.
#
#
#
# #### Example 1:
#
# ![title](btree1.jpg)
#
# ```
# Input: nums = [-10,-3,0,5,9]
# Output: [0,-3,9,-10,null,5]
# Explanation: [0,-10,5,null,-3,null,9] is also accepted:
# ```
# #### Example 2:
#
# ![title](btree2.jpg)
#
# ```
# Input: nums = [1,3]
# Output: [3,1]
# Explanation: [1,3] and [3,1] are both a height-balanced BSTs.
# ```
#
# #### Constraints:
#
# ![title](btree.jpg)
#
# ```
# 1 <= nums.length <= 104
# -104 <= nums[i] <= 104
# nums is sorted in a strictly increasing order.
# ```

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution(object):
    def sortedArrayToBST(self, nums):
        """
        :type nums: List[int]
        :rtype: TreeNode
        """
        if not nums: return None
        _len = len(nums)
        mid = _len // 2
        root = TreeNode(nums[mid])
        root.left = self.sortedArrayToBST(nums[:mid])
        root.right = self.sortedArrayToBST(nums[mid+1:])
        return root

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        if(len(nums) == 0):
            return None
        i=floor(len(nums)/2)
        root = TreeNode(nums[i])
        '''
        def placenodes(nums: List[int]) -> TreeNode:
            if(len(nums) > 0):
                i=floor(len(nums)/2)
                root = TreeNode(nums[i])
                root.left=placenodes(nums[:i])
                root.right=placenodes(nums[i+1:])
                return root
            return None
            
        if(len(nums) > 1):
            root.left=placenodes(nums[:i])
            root.right=placenodes(nums[i+1:])
        '''
        def placenodes(s:int,e:int) -> TreeNode:
            if((e-s) > 0):
                i=floor((e+s)/2)
                root = TreeNode(nums[i])
                root.left=placenodes(s,i)
                root.right=placenodes(i+1,e)
                return root
            return None
            
        if(len(nums) > 1):
            root.left=placenodes(0,i)
            root.right=placenodes(i+1,len(nums))
        return root

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        def helper(nums, start, end):
            if end < start:
                return None
            if start == end:
                return TreeNode(nums[start])
            mid = (start + end) //2
            subtree_root = TreeNode(nums[mid])
            subtree_root.left = helper(nums, start, mid-1)
            subtree_root.right = helper(nums, mid+1, end)
            return subtree_root
        return helper(nums, 0, len(nums)-1)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        
        def make_tree(lst):
            if not lst:
                return None
            l = len(lst)
            mid = l//2
            node = TreeNode(lst[mid])
            node.left = make_tree(lst[:mid])
            node.right = make_tree(lst[mid+1:])
            return node
         
        return make_tree(nums)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        def helper(l, h):
            if l > h:
                return None
            m = l + (h-l) // 2
            node = TreeNode(nums[m])
            node.left = helper(l, m-1)
            node.right = helper(m+1, h)
            return node
        
        return helper(0, len(nums) - 1)
